# %%
# !pip install tensorflow
# !pip install tf-slim
# !pip install tensorflow-object-detection-api
# Out:
# Requirement already satisfied: tensorflow in ./.conda/envs/default/lib/python3.9/site-packages (2.17.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: wrapt>=1.11.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: keras>=3.2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: termcolor>=1.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (24.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: absl-py>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (70.0.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: six>=1.12.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: libclang>=13.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.conda/envs/default/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: namex in ./.conda/envs/default/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: rich in ./.conda/envs/default/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: optree in ./.conda/envs/default/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/default/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/default/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: markdown>=2.6.8 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.conda/envs/default/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in ./.conda/envs/default/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.conda/envs/default/lib/python3.9/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: absl-py>=0.2.2 in ./.conda/envs/default/lib/python3.9/site-packages (from tf-slim) (2.1.0)
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.1.0
# Collecting tensorflow-object-detection-api
#   Downloading tensorflow_object_detection_api-0.1.1.tar.gz (577 kB)
#      |████████████████████████████████| 577 kB 5.0 MB/s eta 0:00:01
# Requirement already satisfied: Pillow>=1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow-object-detection-api) (10.4.0)
# Requirement already satisfied: Matplotlib>=2.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow-object-detection-api) (3.9.2)
# Collecting Cython>=0.28.1
#   Downloading Cython-3.0.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 81.8 MB/s eta 0:00:01
# Requirement already satisfied: Protobuf in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow-object-detection-api) (3.20.3)
# Collecting lxml
#   Downloading lxml-5.3.0-cp39-cp39-manylinux_2_28_x86_64.whl (5.0 MB)
#      |████████████████████████████████| 5.0 MB 91.4 MB/s eta 0:00:01
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: tensorflow in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow-object-detection-api) (2.17.0)
# Collecting contextlib2
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: wheel in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow-object-detection-api) (0.43.0)
# Collecting twine
#   Downloading twine-6.0.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: numpy>=1.23 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.26.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (4.54.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (6.4.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.9.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from importlib-resources>=3.2.0->Matplotlib>=2.1->tensorflow-object-detection-api) (3.17.0)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/default/lib/python3.9/site-packages (from python-dateutil>=2.7->Matplotlib>=2.1->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: nbconvert in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter->tensorflow-object-detection-api) (7.16.4)
# Requirement already satisfied: ipykernel in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter->tensorflow-object-detection-api) (6.4.2)
# Requirement already satisfied: jupyterlab in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter->tensorflow-object-detection-api) (4.1.5)
# Requirement already satisfied: notebook in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter->tensorflow-object-detection-api) (7.1.3)
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: ipywidgets in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter->tensorflow-object-detection-api) (7.8.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.14.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.1.7)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (7.33.0)
# Requirement already satisfied: ipython-genutils in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (7.4.9)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.8.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (3.0.42)
# Requirement already satisfied: decorator in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (5.1.1)
# Requirement already satisfied: pygments in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.18.0)
# Requirement already satisfied: pexpect>4.3 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (4.9.0)
# Requirement already satisfied: setuptools>=18.5 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (70.0.0)
# Requirement already satisfied: backcall in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: pickleshare in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in ./.conda/envs/default/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.19.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.conda/envs/default/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter->tensorflow-object-detection-api) (5.7.2)
# Requirement already satisfied: pyzmq>=23.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter->tensorflow-object-detection-api) (26.0.3)
# Requirement already satisfied: entrypoints in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter->tensorflow-object-detection-api) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter->tensorflow-object-detection-api) (1.6.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-core>=4.9.2->jupyter-client<8.0->ipykernel->jupyter->tensorflow-object-detection-api) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.conda/envs/default/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.7.0)
# Requirement already satisfied: wcwidth in ./.conda/envs/default/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in ./.conda/envs/default/lib/python3.9/site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (1.1.7)
# Requirement already satisfied: widgetsnbextension~=3.6.5 in ./.conda/envs/default/lib/python3.9/site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.6.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter->tensorflow-object-detection-api) (2.14.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.2.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./.conda/envs/default/lib/python3.9/site-packages (from notebook->jupyter->tensorflow-object-detection-api) (2.27.2)
# Requirement already satisfied: websocket-client>=1.7 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.8.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.8.3)
# Requirement already satisfied: overrides>=5.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (7.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (23.1.0)
# Requirement already satisfied: anyio>=3.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (4.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (3.1.4)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.5.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.18.1)
# Requirement already satisfied: nbformat>=5.3.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (5.10.4)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.1 in ./.conda/envs/default/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (4.11.0)
# Requirement already satisfied: idna>=2.8 in ./.conda/envs/default/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.conda/envs/default/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.2.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.conda/envs/default/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.1.5)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (4.22.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.0.7)
# Requirement already satisfied: referencing in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.35.1)
# Requirement already satisfied: pyyaml>=5.3 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (6.0.1)
# Requirement already satisfied: rfc3339-validator in ./.conda/envs/default/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.1.4)
# Requirement already satisfied: attrs>=22.2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (23.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.18.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2023.12.1)
# Requirement already satisfied: uri-template in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: isoduration in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.4)
# Requirement already satisfied: fqdn in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.5.1)
# Requirement already satisfied: webcolors>=1.11 in ./.conda/envs/default/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.13)
# Requirement already satisfied: async-lru>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (0.27.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (7.1.0)
# Requirement already satisfied: tomli in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.0.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.2.5)
# Requirement already satisfied: httpcore==1.* in ./.conda/envs/default/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.0.5)
# Requirement already satisfied: certifi in ./.conda/envs/default/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2024.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.conda/envs/default/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.14.0)
# Requirement already satisfied: babel>=2.10 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.9.25)
# Requirement already satisfied: requests>=2.31 in ./.conda/envs/default/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.12.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.10.0)
# Requirement already satisfied: tinycss2 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: defusedxml in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.1)
# Requirement already satisfied: bleach!=5.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (6.1.0)
# Requirement already satisfied: webencodings in ./.conda/envs/default/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.conda/envs/default/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.19.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/envs/default/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (3.3.2)
# Requirement already satisfied: cffi>=1.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: pycparser in ./.conda/envs/default/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.22)
# Requirement already satisfied: soupsieve>1.2 in ./.conda/envs/default/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection-api) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in ./.conda/envs/default/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.conda/envs/default/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.9.0.20240316)
# Collecting ipykernel
#   Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 71.6 MB/s eta 0:00:01
# Requirement already satisfied: psutil in ./.conda/envs/default/lib/python3.9/site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (0.37.1)
# Requirement already satisfied: absl-py>=1.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (2.1.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (24.3.25)
# Requirement already satisfied: astunparse>=1.6.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (2.4.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (2.17.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (0.4.1)
# Requirement already satisfied: wrapt>=1.11.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (3.4.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (0.6.0)
# Requirement already satisfied: keras>=3.2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (3.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (1.66.1)
# Requirement already satisfied: h5py>=3.10.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorflow->tensorflow-object-detection-api) (18.1.1)
# Requirement already satisfied: namex in ./.conda/envs/default/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow->tensorflow-object-detection-api) (0.0.8)
# Requirement already satisfied: optree in ./.conda/envs/default/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow->tensorflow-object-detection-api) (0.12.1)
# Requirement already satisfied: rich in ./.conda/envs/default/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow->tensorflow-object-detection-api) (13.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow->tensorflow-object-detection-api) (3.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow->tensorflow-object-detection-api) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.conda/envs/default/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow->tensorflow-object-detection-api) (3.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from rich->keras>=3.2.0->tensorflow->tensorflow-object-detection-api) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.conda/envs/default/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->tensorflow-object-detection-api) (0.1.2)
# Collecting readme-renderer>=35.0
#   Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Collecting rfc3986>=1.4.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting keyring>=15.1
#   Downloading keyring-25.5.0-py3-none-any.whl (39 kB)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 8.6 MB/s  eta 0:00:01
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.12.0-py3-none-any.whl (32 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 13.8 MB/s eta 0:00:01
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jaraco.context
#   Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Collecting jaraco.functools
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Collecting nh3>=0.2.14
#   Downloading nh3-0.2.19-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (748 kB)
#      |████████████████████████████████| 748 kB 76.0 MB/s eta 0:00:01
# Collecting docutils>=0.21.2
#   Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#      |████████████████████████████████| 587 kB 70.5 MB/s eta 0:00:01
# Collecting cryptography>=2.0
#   Downloading cryptography-44.0.0-cp39-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 33.8 MB/s eta 0:00:01
# Collecting more-itertools
#   Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 23.9 MB/s eta 0:00:01
# Collecting backports.tarfile
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Building wheels for collected packages: tensorflow-object-detection-api
#   Building wheel for tensorflow-object-detection-api (setup.py) ... done
#   Created wheel for tensorflow-object-detection-api: filename=tensorflow_object_detection_api-0.1.1-py3-none-any.whl size=844488 sha256=6cd38dd4a4cc64baba80fb2062bf76b042ce639f36e528bf9fd9f72fb5baa76f
#   Stored in directory: /home/studio-lab-user/.cache/pip/wheels/38/6f/73/3c0c70f9a8219c31c96c495b686af1416154b60707fd96a4cd
# Successfully built tensorflow-object-detection-api
# Installing collected packages: ipykernel, more-itertools, jeepney, cryptography, backports.tarfile, SecretStorage, nh3, jaraco.functools, jaraco.context, jaraco.classes, docutils, rfc3986, requests-toolbelt, readme-renderer, pkginfo, keyring, jupyter-console, twine, lxml, jupyter, Cython, contextlib2, tensorflow-object-detection-api
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.4.2
#     Uninstalling ipykernel-6.4.2:
#       Successfully uninstalled ipykernel-6.4.2
# Successfully installed Cython-3.0.11 SecretStorage-3.3.3 backports.tarfile-1.2.0 contextlib2-21.6.0 cryptography-44.0.0 docutils-0.21.2 ipykernel-6.29.5 jaraco.classes-3.4.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 jeepney-0.8.0 jupyter-1.1.1 jupyter-console-6.6.3 keyring-25.5.0 lxml-5.3.0 more-itertools-10.5.0 nh3-0.2.19 pkginfo-1.12.0 readme-renderer-44.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 tensorflow-object-detection-api-0.1.1 twine-6.0.1

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import tarfile
import requests
import glob

# Helper function to download and extract PASCAL VOC 2007 dataset
def download_and_extract_voc2007():
    url = "http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar"
    target_dir = "./VOC2007"
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
        print("Downloading PASCAL VOC 2007 dataset...")
        response = requests.get(url, stream=True)
        tar_file = os.path.join(target_dir, "VOC2007.tar")
        with open(tar_file, "wb") as f:
            f.write(response.raw.read())
        print("Extracting dataset...")
        with tarfile.open(tar_file, "r") as tar:
            tar.extractall(path=target_dir)
        os.remove(tar_file)
        print("Dataset downloaded and extracted.")
    else:
        print("PASCAL VOC 2007 dataset already exists.")
    return os.path.join(target_dir, "VOCdevkit", "VOC2007")

# Load and preprocess an image from the dataset
def load_image(image_path):
    image = Image.open(image_path).convert("RGB")
    image = np.array(image)
    input_tensor = tf.convert_to_tensor(image)
    input_tensor = input_tensor[tf.newaxis, ...]  # Add batch dimension
    return image, input_tensor

# Display the image with bounding boxes and labels
def display_image_with_boxes(image, boxes, class_names, scores, threshold=0.5):
    plt.figure(figsize=(10, 10))
    plt.imshow(image)
    ax = plt.gca()

    for box, cls, score in zip(boxes, class_names, scores):
        if score >= threshold:
            ymin, xmin, ymax, xmax = box
            rect = plt.Rectangle(
                (xmin * image.shape[1], ymin * image.shape[0]),
                (xmax - xmin) * image.shape[1],
                (ymax - ymin) * image.shape[0],
                fill=False,
                color="red",
                linewidth=2,
            )
            ax.add_patch(rect)
            ax.text(
                xmin * image.shape[1],
                ymin * image.shape[0],
                f"{cls}: {score:.2f}",
                bbox=dict(facecolor="yellow", alpha=0.5),
                fontsize=10,
                color="black",
            )
    plt.axis("off")
    plt.show()

# Main function
def main():
    # Step 1: Download and prepare dataset
    voc_dir = download_and_extract_voc2007()
    
    # Dynamically select the first image in the directory
    image_files = glob.glob(os.path.join(voc_dir, "JPEGImages", "*.jpg"))
    if not image_files:
        raise FileNotFoundError("No images found in the VOC2007/JPEGImages directory.")
    sample_image_path = image_files[0]
    print(f"Using sample image: {sample_image_path}")

    # Step 2: Load TensorFlow Hub Faster R-CNN model
    print("Loading Faster R-CNN model from TensorFlow Hub...")
    model_handle = "https://tfhub.dev/tensorflow/faster_rcnn/resnet50_v1_640x640/1"
    detector = hub.load(model_handle)
    print("Model loaded successfully.")

    # Step 3: Load and preprocess image
    image, input_tensor = load_image(sample_image_path)

    # Step 4: Run inference
    print("Running inference...")
    detections = detector(input_tensor)

    # Extract detection outputs
    boxes = detections["detection_boxes"][0].numpy()
    class_indices = detections["detection_classes"][0].numpy().astype(int)
    scores = detections["detection_scores"][0].numpy()

    # Map class indices to VOC labels (ensuring correct range)
    voc_labels = ["background", "aeroplane", "bicycle", "bird", "boat", "bottle",
                  "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse",
                  "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]

    # Filter invalid indices
    class_names = [
        voc_labels[idx] if idx < len(voc_labels) else "unknown"
        for idx in class_indices
    ]

    # Step 5: Display results
    display_image_with_boxes(image, boxes, class_names, scores)

if __name__ == "__main__":
    main()
# Out:
# PASCAL VOC 2007 dataset already exists.
# Using sample image: ./VOC2007/VOCdevkit/VOC2007/JPEGImages/000005.jpg
# Loading Faster R-CNN model from TensorFlow Hub...
# Model loaded successfully.
# Running inference...
